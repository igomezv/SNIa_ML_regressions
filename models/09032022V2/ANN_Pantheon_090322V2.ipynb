# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1" #model will be trained on GPU 1

# %%
import tensorflow.keras
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import gzip
# %matplotlib inline
from tensorflow.keras.layers import Input,Conv2D,MaxPooling2D,UpSampling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import Constant, RandomNormal
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.misc import derivative
import scipy.integrate as intg
import scipy as sp
from scipy.interpolate import interp1d

# %%
import pandas as pd
df=pd.read_csv('/content/jla.csv')

# %%
dmag =df["dmb"]

# %%
N = len(df.values)

# %%
df2=df['errors']+df['dmb']

# %%
plt.figure(figsize=(10, 7), dpi=100)
plt.errorbar(df['zcmb'], df['mb']+19, df2, fmt='g.', markersize=5, label='Observations', alpha=0.5)
plt.xlabel("Redshift z", fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
# plt.xscale('log')


plt.ylabel("$\mu(z)$", fontsize=20)
plt.xlim(0, 1.5)
# Out:
# (0.0, 1.5)

# %%
randomize = np.random.permutation(N)
data = df.values[randomize]

# %%
z = data[:,0]
y = data[:,1:] ### coge el resto de variables a predecir 
# print(randomize)

# %%
scalerz = StandardScaler()
# scalerz = MinMaxScaler(feature_range=(-1,1))
# fit scaler on data
scalerz.fit(z.reshape(-1,1))
# apply transform
z = scalerz.transform(z.reshape(-1,1))

# scalery = MinMaxScaler(feature_range=(0,1))
# scalery = StandardScaler()
# scalery.fit(y)
# y = scalery.transform(y)

# %%
### Modificar para incluir phanteon como test
split = 0.7
ntrain = int(split * len(z))
indx = [ntrain]
z_train, z_test = np.split(z, indx)
y_train, y_test = np.split(y, indx)

# %%
callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min',
                                   min_delta=0.01,
                                   patience=50.0,
                                   restore_best_weights=True)]
#                      tf.keras.callbacks.ReduceLROnPlateau(patience=2)]

# %% [markdown]
# COMBINACIONES ÓPTIMAS DE HIPERPARÁMETROS![hiper.png](data:image/png;base64,...)

# %%
def model(input_z):
    efirst = Dense(100, activation='relu', input_shape=(1,))(input_z)
    ehidden = Dense(150, activation='relu')(efirst)
    ehidden2 = Dense(200, activation='relu')(ehidden)
    ehidden3 = Dense(150, activation='relu')(ehidden2)
    elast = Dense(3, activation='linear')(ehidden3) ### cambiar segun el número de variables a predecir
    return elast


input_z = Input(shape = (1,))
neural_model = Model(input_z, model(input_z))
neural_model.compile(loss='mean_squared_error', optimizer = "adam")
neural_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 1)]               0
#
#  dense_10 (Dense)            (None, 100)               200
#
#  dense_11 (Dense)            (None, 150)               15150
#
#  dense_12 (Dense)            (None, 200)               30200
#
#  dense_13 (Dense)            (None, 150)               30150
#
#  dense_14 (Dense)            (None, 3)                 453
#
# =================================================================
# Total params: 76,153
# Trainable params: 76,153
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 1
epochs = 200
input_z = Input(shape = (1,))

# %%
model_train = neural_model.fit(z_train, y_train, batch_size=batch_size,
                                    epochs=epochs,verbose=1,
                                    validation_data=(z_test, y_test),
                                    callbacks=callbacks)
# Out:
# Epoch 1/200
# 626/626 [==============================] - 3s 4ms/step - loss: 12.9413 - val_loss: 0.2983
# Epoch 2/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.2338 - val_loss: 0.0966
# Epoch 3/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.1173 - val_loss: 0.1120
# Epoch 4/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.2072 - val_loss: 0.1900
# Epoch 5/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.1891 - val_loss: 0.2043
# Epoch 6/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0767 - val_loss: 0.1106
# Epoch 7/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.1110 - val_loss: 0.0379
# Epoch 8/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.2161 - val_loss: 0.2382
# Epoch 9/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.1692 - val_loss: 0.5500
# Epoch 10/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.1119 - val_loss: 0.2016
# Epoch 11/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.1864 - val_loss: 0.0652
# Epoch 12/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0798 - val_loss: 0.0476
# Epoch 13/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0961 - val_loss: 0.0278
# Epoch 14/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0840 - val_loss: 0.0474
# Epoch 15/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.1553 - val_loss: 0.2108
# Epoch 16/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0746 - val_loss: 0.0911
# Epoch 17/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0571 - val_loss: 0.0227
# Epoch 18/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0505 - val_loss: 0.0981
# Epoch 19/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0718 - val_loss: 0.3205
# Epoch 20/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0787 - val_loss: 0.1877
# Epoch 21/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0530 - val_loss: 0.0162
# Epoch 22/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0458 - val_loss: 0.0148
# Epoch 23/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0749 - val_loss: 0.0480
# Epoch 24/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0464 - val_loss: 0.0162
# Epoch 25/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0753 - val_loss: 0.0259
# Epoch 26/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0385 - val_loss: 0.0466
# Epoch 27/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0452 - val_loss: 0.0208
# Epoch 28/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0469 - val_loss: 0.0591
# Epoch 29/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0631 - val_loss: 0.0315
# Epoch 30/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0362 - val_loss: 0.0699
# Epoch 31/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0380 - val_loss: 0.0175
# Epoch 32/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0477 - val_loss: 0.0723
# Epoch 33/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0415 - val_loss: 0.0255
# Epoch 34/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0408 - val_loss: 0.0645
# Epoch 35/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0336 - val_loss: 0.0123
# Epoch 36/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0419 - val_loss: 0.0270
# Epoch 37/200
# 626/626 [==============================] - 2s 4ms/step - loss: 0.0377 - val_loss: 0.0934
# Epoch 38/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0411 - val_loss: 0.0210
# Epoch 39/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0376 - val_loss: 0.0651
# Epoch 40/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0391 - val_loss: 0.0163
# Epoch 41/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0352 - val_loss: 0.0126
# Epoch 42/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0379 - val_loss: 0.0327
# Epoch 43/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0271 - val_loss: 0.0899
# Epoch 44/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0333 - val_loss: 0.0452
# Epoch 45/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0259 - val_loss: 0.0158
# Epoch 46/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0332 - val_loss: 0.0558
# Epoch 47/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0321 - val_loss: 0.0191
# Epoch 48/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0321 - val_loss: 0.0234
# Epoch 49/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0302 - val_loss: 0.0619
# Epoch 50/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0319 - val_loss: 0.0529
# Epoch 51/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0305 - val_loss: 0.0201
# Epoch 52/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0275 - val_loss: 0.0238
# Epoch 53/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0269 - val_loss: 0.0133
# Epoch 54/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0270 - val_loss: 0.0915
# Epoch 55/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0319 - val_loss: 0.0245
# Epoch 56/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0226 - val_loss: 0.0150
# Epoch 57/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0257 - val_loss: 0.0136
# Epoch 58/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0269 - val_loss: 0.0144
# Epoch 59/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0303 - val_loss: 0.0229
# Epoch 60/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0230 - val_loss: 0.0499
# Epoch 61/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0270 - val_loss: 0.0286
# Epoch 62/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0320 - val_loss: 0.0127
# Epoch 63/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0287 - val_loss: 0.0645
# Epoch 64/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0259 - val_loss: 0.0229
# Epoch 65/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0229 - val_loss: 0.0242
# Epoch 66/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0282 - val_loss: 0.0136
# Epoch 67/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0228 - val_loss: 0.0109
# Epoch 68/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0233 - val_loss: 0.0227
# Epoch 69/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0287 - val_loss: 0.0172
# Epoch 70/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0279 - val_loss: 0.0412
# Epoch 71/200
# 626/626 [==============================] - 2s 3ms/step - loss: 0.0243 - val_loss: 0.0256

# %%
plt.plot(model_train.history['loss'], color='r', )
plt.plot(model_train.history['val_loss'], color='g')

plt.ylabel('MSE', fontsize=11)
plt.xlabel('Epoch', fontsize=11)
plt.legend(['training set', 'validation set'], loc='upper right', fontsize=12)
# plt.savefig('loss_hz.png')

# %%
neural_model.save('FFNN_v2.h5')

# %%
pred = neural_model.predict(z_test)
pred
# Out:
# array([[23.391731  ,  0.16229168,  0.18924676],
#        [24.058258  ,  0.17130898,  0.19518362],
#        [23.487553  ,  0.1637642 ,  0.19052444],
#        [16.596964  ,  0.13881406,  0.16186057],
#        [20.02666   ,  0.1422761 ,  0.16302358],
#        [15.198331  ,  0.14343607,  0.16431092],
#        [21.129074  ,  0.14648929,  0.16883193],
#        [22.385426  ,  0.15215689,  0.17753588],
#        [23.07726   ,  0.15884864,  0.18528925],
#        [15.180785  ,  0.14353295,  0.16434251],
#        [15.652696  ,  0.14103055,  0.16368459],
#        [21.969872  ,  0.1497315 ,  0.17441688],
#        [16.198431  ,  0.13933215,  0.16276668],
#        [21.891731  ,  0.14926142,  0.17375813],
#        [21.761953  ,  0.1484802 ,  0.17266546],
#        [20.261585  ,  0.14316744,  0.16428743],
#        [21.545462  ,  0.14738543,  0.17099033],
#        [17.255346  ,  0.13834548,  0.16041814],
#        [21.755157  ,  0.14843968,  0.172608  ],
#        [22.502522  ,  0.15307255,  0.1784905 ],
#        [24.060007  ,  0.17133135,  0.19519411],
#        [23.721727  ,  0.16707581,  0.19323884],
#        [21.440437  ,  0.14715992,  0.17043959],
#        [21.41418   ,  0.14710651,  0.17030631],
#        [20.157059  ,  0.14275855,  0.16371714],
#        [21.672268  ,  0.14791614,  0.17191397],
#        [21.812235  ,  0.14878294,  0.17308865],
#        [24.48891   ,  0.17655277,  0.19747792],
#        [20.688866  ,  0.14486091,  0.16673099],
#        [16.100077  ,  0.1395462 ,  0.16296147],
#        [18.950512  ,  0.14068183,  0.16000472],
#        [23.421337  ,  0.1627473 ,  0.18964182],
#        [15.6132145 ,  0.14123866,  0.1637368 ],
#        [22.479801  ,  0.15289137,  0.17831884],
#        [19.367184  ,  0.14124951,  0.16101156],
#        [22.096804  ,  0.1504702 ,  0.1754161 ],
#        [24.428839  ,  0.17580637,  0.19716106],
#        [21.567406  ,  0.14745802,  0.1711434 ],
#        [14.858163  ,  0.14583501,  0.16540931],
#        [21.764675  ,  0.14849651,  0.17268811],
#        [22.420967  ,  0.15243396,  0.17783414],
#        [19.39653   ,  0.14129621,  0.16108333],
#        [20.094685  ,  0.1425145 ,  0.1633762 ],
#        [21.07109   ,  0.14636251,  0.16853176],
#        [21.141075  ,  0.1465148 ,  0.16889392],
#        [23.395779  ,  0.16235417,  0.18930112],
#        [22.381748  ,  0.15212807,  0.1775056 ],
#        [24.158247  ,  0.17256057,  0.1957017 ],
#        [18.228409  ,  0.13943377,  0.15937434],
#        [22.028301  ,  0.15008307,  0.17490993],
#        [22.306915  ,  0.15164295,  0.17693244],
#        [20.395954  ,  0.1436935 ,  0.16502057],
#        [14.754251  ,  0.14659557,  0.16576432],
#        [20.64067   ,  0.1446419 ,  0.16650401],
#        [20.62873   ,  0.1445964 ,  0.1664282 ],
#        [16.237898  ,  0.13926211,  0.16266929],
#        [22.238083  ,  0.15125903,  0.1764351 ],
#        [21.126822  ,  0.14648433,  0.16882001],
#        [23.79504   ,  0.16801521,  0.19382416],
#        [23.490952  ,  0.16381648,  0.19056974],
#        [20.822643  ,  0.14542921,  0.16735493],
#        [22.033737  ,  0.15011595,  0.17495523],
#        [20.367666  ,  0.14358231,  0.16486536],
#        [22.656113  ,  0.15477216,  0.18011795],
#        [23.288612  ,  0.16083689,  0.18793355],
#        [22.76112   ,  0.1558285 ,  0.18130027],
#        [23.357603  ,  0.16176769,  0.18879281],
#        [20.728752  ,  0.14504458,  0.166916  ],
#        [23.784185  ,  0.16787922,  0.19376741],
#        [22.081306  ,  0.15038371,  0.17530428],
#        [22.68273   ,  0.15504324,  0.1804155 ],
#        [15.862006  ,  0.14010003,  0.16338454],
#        [22.35986   ,  0.15196337,  0.1773263 ],
#        [16.665302  ,  0.13876848,  0.16171144],
#        [24.254272  ,  0.1737391 ,  0.19622622],
#        [16.014874  ,  0.13974342,  0.16311489],
#        [20.885952  ,  0.14567515,  0.16765247],
#        [23.366951  ,  0.1619115 ,  0.18891631],
#        [16.70104   ,  0.13874325,  0.16163586],
#        [21.300621  ,  0.14686161,  0.16971956],
#        [23.983269  ,  0.17037073,  0.19479619],
#        [20.974339  ,  0.14601871,  0.16806827],
#        [21.25713   ,  0.14676742,  0.1694945 ],
#        [22.096256  ,  0.15046743,  0.17541276],
#        [18.921555  ,  0.14065889,  0.15991019],
#        [21.506008  ,  0.14729303,  0.17077075],
#        [18.063702  ,  0.13909566,  0.15932463],
#        [16.095694  ,  0.13955617,  0.16297017]], dtype=float32)

# %%
# ranz = np.random.uniform(0, 2, size=10000)
ranz = np.linspace(0, 1.5, 1000)
r = scalerz.transform(ranz.reshape(-1, 1))
pred_random = neural_model.predict(r)
rr = scalerz.inverse_transform(r.reshape(-1,1))

# %%
plt.figure(figsize=(10, 7), dpi=100)
plt.errorbar(df['zcmb'], df['mb'], df2, fmt='g.', markersize=15, label='Observations', alpha=0.5)
plt.errorbar(rr, pred_random[:,0], pred_random[:,1], markersize=2, fmt='o', 
             ecolor='r', capthick=2, elinewidth=0.8, alpha=0.5, c='m')
plt.xlabel("Redshift z", fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)


plt.ylabel("$\mu(z)$", fontsize=20)
plt.xlim(0, 1.5)
plt.savefig("errors_jla.png")

# %%
def RHSquared_a_owacdm(a, w0, wa, Om):
    rhow = a**(-3*(1.0+w0+wa))*np.exp(-3*wa*(1-a))
    return (Om/a**3+(1.0-Om)*rhow)

def DistIntegrand_a(a, w0, wa, Om):
        return 1./np.sqrt(RHSquared_a_owacdm(a, w0, wa, Om))/a**2
    
def Da_z(z, w0, wa, Om):
        r = intg.quad(DistIntegrand_a, 1./(1+z), 1, args=(w0, wa, Om))
        r = r[0]
        return r

### Hay que revisar esta constante en el return
def distance_modulus(z, w0=-1, wa=0.0, Om=0.23):
    return 5*np.log10(Da_z(z, w0, wa, Om)*(1+z))+24
# +43

zmodel = np.linspace(0.01, 1.5, 100)
flcdm = []
# fowacdm1 = []
# fowacdm2 = []
# fowacdm3 = []

om = 0.27
for zzz in zmodel:
    flcdm.append(distance_modulus(zzz, w0=-1, wa=0, Om=om))

#     fowacdm1.append(distance_modulus(zzz, w0=-1.3, wa=1.2))
#     fowacdm1.append(distance_modulus(zzz, w0=-1.09, wa=0.3, Om=om))
#     fowacdm2.append(distance_modulus(zzz, w0=-1.04, wa=-0.3, Om=om))
#     fowacdm3.append(distance_modulus(zz, model='owacdm', w0=-1, wa=0.0))
    
flcdm = np.array(flcdm)
# fowacdm1 = np.array(fowacdm1)
# fowacdm2 = np.array(fowacdm2)
# fowacdm3 = np.array(fowacdm3)

# %%
plt.figure(figsize=(10, 7), dpi=100)

plt.errorbar(df['zcmb'], df['mb'], yerr=df2, fmt='g.', label='Observations')
# plt.plot(df['zcmb'], df['mb'], c='g')
plt.plot(zmodel, flcdm, label='$\Lambda CDM$', c='b')
plt.errorbar(rr, pred_random[:,0], pred_random[:,1], markersize=2, fmt='o', 
             ecolor='r', capthick=2, elinewidth=0.8, alpha=0.5, c='m', label='neural')
plt.ylabel("$\mu(z)$", fontsize=14)
plt.legend(fontsize=14, loc='lower right', framealpha=0.9, ncol=1)

                            


plt.xlabel('Redshift $z$', fontsize=14)

plt.savefig("jla.png")

# %% [markdown]
# PREDICCIÓN SOBRE EL CONJUNTO DE PHANTEON TESTEO

# %%
import pandas as pd
df=pd.read_csv('/content/not_in _jla.csv')

# %%
dmag =df["dmb"]

# %%
N = len(df.values)

# %%
df2=df['errors']+df['dmb']

# %%
plt.figure(figsize=(10, 7), dpi=100)
plt.errorbar(df['zcmb'], df['mb']+19, df2, fmt='g.', markersize=5, label='Observations', alpha=0.5)
plt.xlabel("Redshift z", fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
# plt.xscale('log')


plt.ylabel("$\mu(z)$", fontsize=20)
plt.xlim(0, 1.5)
# Out:
# (0.0, 1.5)

# %%
randomize = np.random.permutation(N)
data = df.values[randomize]

# %%
z = data[:,0]
y = data[:,1:] ### coge el resto de variables a predecir 
# print(randomize)

# %%
scalerz = StandardScaler()
# scalerz = MinMaxScaler(feature_range=(-1,1))
# fit scaler on data
scalerz.fit(z.reshape(-1,1))
# apply transform
z = scalerz.transform(z.reshape(-1,1))

# scalery = MinMaxScaler(feature_range=(0,1))
# scalery = StandardScaler()
# scalery.fit(y)
# y = scalery.transform(y)

# %%
### Modificar para incluir phanteon como test
split = 0.0
ntrain = int(split * len(z))
indx = [ntrain]
z_train, z_test = np.split(z, indx)
y_train, y_test = np.split(y, indx)

# %%
len(z_test)
# Out:
# 895

# %%
from keras.models import load_model

# %%
neural_model = load_model('/content/FFNN_v2.h5')

# %%
pred = neural_model.predict(z_test)
pred
# Out:
# array([[22.054466  ,  0.15023404,  0.17511116],
#        [22.636438  ,  0.15455297,  0.1799091 ],
#        [15.825035  ,  0.14018527,  0.16344641],
#        ...,
#        [23.912884  ,  0.16948973,  0.1944326 ],
#        [21.341698  ,  0.14695069,  0.169932  ],
#        [20.7819    ,  0.1452711 ,  0.167163  ]], dtype=float32)

# %%
# ranz = np.random.uniform(0, 2, size=10000)
ranz = np.linspace(0, 1.5, 1000)
r = scalerz.transform(ranz.reshape(-1, 1))
pred_random = neural_model.predict(r)
rr = scalerz.inverse_transform(r.reshape(-1,1))

# %%
plt.figure(figsize=(10, 7), dpi=100)
plt.errorbar(df['zcmb'], df['mb'], df2, fmt='g.', markersize=10, label='Observations', alpha=0.5)
plt.errorbar(rr, pred_random[:,0], pred_random[:,1], markersize=2, fmt='o', 
             ecolor='r', capthick=2, elinewidth=0.8, alpha=0.5, c='m')

plt.xlabel("Redshift z", fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)


plt.ylabel("$\mu(z)$", fontsize=20)
plt.xlim(0, 1.5)
plt.savefig("errors2.png")

# %%
def RHSquared_a_owacdm(a, w0, wa, Om):
    rhow = a**(-3*(1.0+w0+wa))*np.exp(-3*wa*(1-a))
    return (Om/a**3+(1.0-Om)*rhow)

def DistIntegrand_a(a, w0, wa, Om):
        return 1./np.sqrt(RHSquared_a_owacdm(a, w0, wa, Om))/a**2
    
def Da_z(z, w0, wa, Om):
        r = intg.quad(DistIntegrand_a, 1./(1+z), 1, args=(w0, wa, Om))
        r = r[0]
        return r

### Hay que revisar esta constante en el return
def distance_modulus(z, w0=-1, wa=0.0, Om=0.23):
    return 5*np.log10(Da_z(z, w0, wa, Om)*(1+z))+24
# +43

zmodel = np.linspace(0.01, 1.5, 100)
flcdm = []
# fowacdm1 = []
# fowacdm2 = []
# fowacdm3 = []

om = 0.27
for zzz in zmodel:
    flcdm.append(distance_modulus(zzz, w0=-1, wa=0, Om=om))

#     fowacdm1.append(distance_modulus(zzz, w0=-1.3, wa=1.2))
#     fowacdm1.append(distance_modulus(zzz, w0=-1.09, wa=0.3, Om=om))
#     fowacdm2.append(distance_modulus(zzz, w0=-1.04, wa=-0.3, Om=om))
#     fowacdm3.append(distance_modulus(zz, model='owacdm', w0=-1, wa=0.0))
    
flcdm = np.array(flcdm)
# fowacdm1 = np.array(fowacdm1)
# fowacdm2 = np.array(fowacdm2)
# fowacdm3 = np.array(fowacdm3)

# %%
plt.figure(figsize=(10, 7), dpi=100)

plt.errorbar(df['zcmb'], df['mb'], yerr=df2, fmt='g.', label='Observations')
# plt.plot(df['zcmb'], df['mb'], c='g')
plt.plot(zmodel, flcdm, label='$\Lambda CDM$', c='b')
plt.errorbar(rr, pred_random[:,0], pred_random[:,1], markersize=2, fmt='o', 
             ecolor='r', capthick=2, elinewidth=0.8, alpha=0.5, c='m', label='neural')
plt.ylabel("$\mu(z)$", fontsize=14)
plt.legend(fontsize=14, loc='lower right', framealpha=0.9, ncol=1)

                            


plt.xlabel('Redshift $z$', fontsize=14)
plt.savefig("prediction2.png")
